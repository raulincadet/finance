# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from fredeco.fredData import fred_series, fred_multi_series, explore   # fredeco can be installed with pip
from fredeco.fredSearch import fred_list_series, fred_info_series, fred_search, fred_vintagedates

# %%
fred_api='82d9884c5a1d1e4a13053f180e201290'

# %%
# dsearch=fred_search(fred_api=fred_api,text='housing market inventory')
dsearch
# Out:
#                             id realtime_start realtime_end  \
# 0                  ACTLISCOUUS     2023-10-15   2023-10-15
# 1                HOSINVUSM495N     2023-10-15   2023-10-15
# 2                MEDDAYONMARUS     2023-10-15   2023-10-15
# 3                  ACTLISCOUFL     2023-10-15   2023-10-15
# 4                  ACTLISCOUCA     2023-10-15   2023-10-15
# ..                         ...            ...          ...
# 995  MEDLISPRIPERSQUFEEYY27460     2023-10-15   2023-10-15
# 996  MEDLISPRIPERSQUFEEMM34940     2023-10-15   2023-10-15
# 997  MEDLISPRIPERSQUFEEMM33460     2023-10-15   2023-10-15
# 998  MEDLISPRIPERSQUFEEYY47260     2023-10-15   2023-10-15
# 999  MEDLISPRIPERSQUFEEMM34980     2023-10-15   2023-10-15
#
#                                                  title observation_start  \
# 0    Housing Inventory: Active Listing Count in the...        2016-07-01
# 1               Existing Home Sales: Housing Inventory        2022-08-01
# ...

# %%
dsearch.title[0],dsearch.notes[0]
# Out:
# ('Housing Inventory: Active Listing Count in Florida',
# ...

# %%
fred_search(fred_api=fred_api,text='Home price index')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\rcadet\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\rcadet\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import re
re.findall('housing','Housing market inventory')
# Out:
# []
